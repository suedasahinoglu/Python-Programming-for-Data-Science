# %% [markdown]
# <a href="https://www.kaggle.com/code/suedasahinoglu/python-exercises-and-list-comprehension?scriptVersionId=194775645" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # CASE STUDY-1:  PYTHON ALIŞTIRMALARI

# %% [markdown]
# ## GÖREV-1:
# ## Verilen değerlerin veri yapılarını inceleyiniz.

# %%
x = 8
type(x)
# Out:
# int

# %%
y = 3.2
type(y)
# Out:
# float

# %%
z = 8j + 18
type(z)
# Out:
# complex

# %%
a = "Hello World"
type(a)
# Out:
# str

# %%
b = True
type(b)
# Out:
# bool

# %%
c = 23 < 22
type(c)
# Out:
# bool

# %%
l = [1, 2, 3, 4]
type(l)
# Out:
# list

# %%
d = {"Name": "Jake",
     "Age": 27,
     "Adress": "Downtown"}
type(d)
# Out:
# dict

# %%
t = ("Machine Learning", "Data Science")
type(t)
# Out:
# tuple

# %%
s = {"Python", "Machine Learning", "Data Science"}
type(s)
# Out:
# set

# %% [markdown]
# ## GÖREV-2:
# ## Verilen string ifadenin tüm harflerini büyük harfe çeviriniz. Virgül ve nokta yerine space koyunuz, kelime kelime ayırınız.
# #### text = "The goal is to turn data into information, and information into insight."
# #### Beklenen Çıktı:
# #### ['THE', 'GOAL', 'IS', 'TO', 'TURN', 'DATA', 'INTO', 'INFORMATION', 'AND', 'INFORMATION', 'INTO', 'INSIGHT']

# %%
text = "The goal is to turn data into information, and information into insight."
text.upper().replace(","," ").replace(".", " ").split()
# Out:
# ['THE',
#  'GOAL',
#  'IS',
#  'TO',
#  'TURN',
#  'DATA',
#  'INTO',
#  'INFORMATION',
#  'AND',
#  'INFORMATION',
#  'INTO',
#  'INSIGHT']

# %% [markdown]
# ## GÖREV-3:
# ## Verilen listeye aşağıdaki adımları uygulayınız.

# %%
lst = ["D", "A", "T", "A", "S", "C", "I", "E", "N", "C", "E"]

# %% [markdown]
# ### # Adım-1:   Verilen listenin eleman sayısına bakınız.

# %%
len(lst)
# Out:
# 11

# %% [markdown]
# ### # Adım-2:   Sıfırıncı ve onuncu indeksteki elemanları çağırınız.

# %%
lst[0]
# Out:
# 'D'

# %%
lst[10]
# Out:
# 'E'

# %% [markdown]
# ### # Adım-3:   Verilen liste üzerinden ["D", "A", "T", "A"] listesi oluşturunuz.

# %%
lst[0:4]
# Out:
# ['D', 'A', 'T', 'A']

# %% [markdown]
# ### # Adım-4:   Sekizinci indeksteki elemanı siliniz.

# %%
lst.pop(8)
# Out:
# 'N'

# %% [markdown]
# ##### ['D', 'A', 'T', 'A', 'S', 'C', 'I', 'E', 'C', 'E']

# %% [markdown]
# ### # Adım-5:   Yeni bir eleman ekleyiniz.

# %%
lst.append(14)

# %% [markdown]
# ##### ['D', 'A', 'T', 'A', 'S', 'C', 'I', 'E', 'C', 'E', 14]

# %% [markdown]
# ### # Adım-6:   Sekizinci indekse "N" elemanını tekrar ekleyiniz.

# %%
lst.insert(8, "N")

# %% [markdown]
# ##### ['D', 'A', 'T', 'A', 'S', 'C', 'I', 'E', 'N', 'C', 'E', 14]

# %% [markdown]
# ## GÖREV-4:
# ## Verilen sözlük yapısına aşağıdaki adımları uygulayınız.

# %%
dict = {'Christian': ["America", 18],
        'Daisy': ["England", 12],
        'Antonio': ["Spain", 22],
        'Dante': ["Italy", 25]}

# %% [markdown]
# ### # Adım-1:   Key değerlerine erişiniz.

# %%
dict.keys()
# Out:
# dict_keys(['Christian', 'Daisy', 'Antonio', 'Dante'])

# %% [markdown]
# ### # Adım-2:   Value'lara erişiniz.

# %%
dict.values()
# Out:
# dict_values([['America', 18], ['England', 12], ['Spain', 22], ['Italy', 25]])

# %% [markdown]
# ### # Adım-3:   Daisy key'ine ait 12 değerini 13 olarak güncelleyiniz.

# %%
dict["Daisy"][1] = 13

# %% [markdown]
# ##### {'Christian': ['America', 18],
# ##### 'Daisy': ['England', 13],
# ##### 'Antonio': ['Spain', 22],
# ##### 'Dante': ['Italy', 25]}

# %% [markdown]
# ### # Adım-4:   Key değeri Ahmet value değeri [Turkey, 24] olan yeni bir değer ekleyiniz.

# %%
dict.update({'Ahmet': ["Turkey", 24]})

# %% [markdown]
# ##### {'Christian': ['America', 18],
# ##### 'Daisy': ['England', 12],
# ##### 'Antonio': ['Spain', 22],
# ##### 'Dante': ['Italy', 25],
# ##### 'Ahmet': ['Turkey', 24]}

# %% [markdown]
# ### # Adım-5:   Antonio'yu dictionary'den siliniz.

# %%
dict.pop("Antonio")
# Out:
# ['Spain', 22]

# %% [markdown]
# ##### {'Christian': ['America', 18],
# ##### 'Daisy': ['England', 12],
# ##### 'Dante': ['Italy', 25],
# ##### 'Ahmet': ['Turkey', 24]}

# %% [markdown]
# ## GÖREV-5:
# ## Argümanları olarak bir liste alan, listenin içerisindeki tek ve çift sayları ayrı listelere atayan ve bu listeleri return eden fonksiyon yazınız.

# %%
l = [2, 13, 18, 93, 22]

# %%
def func(list):
     even_list = []
     odd_list = []
     for i in list:
          if i % 2 == 0:
               even_list.append(i)
          else:
               odd_list.append(i)

     return even_list, odd_list


even_list, odd_list = func(l)

# %%
even_list
# Out:
# [2, 18, 22]

# %%
odd_list
# Out:
# [13, 93]

# %% [markdown]
# ## GÖREV-6:
# ## Aşağıda verilen listede mühendislik ve tıp fakültelerinde dereceye giren öğrencilerin isimleri bulunmaktadır. Sırasıyla ilk üç öğrenci mühendislik fakültesinin başarı sırasını temsil ederken, son üç öğrenci de tıp fakültesi öğrenci sırasına aittir. Enumerate kullanarak öğrenci derecelerini fakülte özelinde yazdırınız.
#
#
#
#
# ###### Beklenen Çıktı:
# ###### Mühendislik Fakültesi 1 . öğrenci: Ali
# ###### Mühendislik Fakültesi 2 . öğrenci: Veli
# ###### Mühendislik Fakültesi 3 . öğrenci: Ayşe
# ###### Tıp Fakültesi 1. öğrenci: Talat
# ###### Tıp Fakültesi 2. öğrenci: Zeynep
# ###### Tıp Fakültesi 3. öğrenci: Ece

# %%
ogrenciler = ["Ali", "Veli", "Ayşe", "Talat", "Zeynep", "Ece"]

# %%
for index, ogrenci in enumerate(ogrenciler, 1):
     if index < 4:
          print(f"Mühendislik Fakültesi {index}. öğrenci: {ogrenci}")
     else:
          print(f"Tıp Fakültesi {index - 3}. öğrenci: {ogrenci}")
# Out:
# Mühendislik Fakültesi 1. öğrenci: Ali
# Mühendislik Fakültesi 2. öğrenci: Veli
# Mühendislik Fakültesi 3. öğrenci: Ayşe
# Tıp Fakültesi 1. öğrenci: Talat
# Tıp Fakültesi 2. öğrenci: Zeynep
# Tıp Fakültesi 3. öğrenci: Ece

# %% [markdown]
# ## GÖREV-7:
# ## Aşağıda 3 adet liste verilmiştir. Listelerde sırası ile; Bir dersin kodu, kredisi ve kontenjan bilgileri yer almaktadır. Zip kullanarak ders bilgilerini bastırınız.
#
#
# ###### Beklenen Çıktı:
# ###### Kredisi 3 olan CMP1005 kodlu dersin kontenjanı 30 kişidir.
# ###### Kredisi 4 olan PSY1001 kodlu dersin kontenjanı 75 kişidir.
# ###### Kredisi 2 olan HUK1005 kodlu dersin kontenjanı 150 kişidir.
# ###### Kredisi 4 olan SEN2204 kodlu dersin kontenjanı 25 kişidir.

# %%
ders_kodu = ["CMP1005", "PSY1001", "HUK1005", "SEN2204"]
kredi = [3, 4, 2, 4]
kontenjan = [30, 75, 150, 25]

# %%
ders_bilgisi = list(zip(ders_kodu, kredi, kontenjan))

# %%
for ders_kodu, kredi, kontenjan in ders_bilgisi:
     print(f"Kredisi {kredi} olan {ders_kodu} kodlu dersin kontenjanı {kontenjan} kişidir.")
# Out:
# Kredisi 3 olan CMP1005 kodlu dersin kontenjanı 30 kişidir.
# Kredisi 4 olan PSY1001 kodlu dersin kontenjanı 75 kişidir.
# Kredisi 2 olan HUK1005 kodlu dersin kontenjanı 150 kişidir.
# Kredisi 4 olan SEN2204 kodlu dersin kontenjanı 25 kişidir.

# %% [markdown]
# ## GÖREV-8:
# ## Aşağıda 2 adet set verilmiştir. Eğer 1. küme 2. kümeyi kapsıyorsa ortak elemanlarını, kapsamıyorsa 2. kümenin 1. kümeden farkını yazdıracak fonksiyonu tanımlayınız.
#
#
#
# ###### Beklenen Çıktı:
# ###### {'function', 'qcut', 'miuul', 'lambda'}

# %%
kume1 = set(["data", "python"])
kume2 = set(["data", "function", "qcut", "lambda", "python", "miuul"])

# %%
def clusters(cluster1, cluster2):
     if cluster1.issuperset(cluster2):
          print(cluster1.intersection(cluster2))
     else:
          print(cluster2.difference(cluster1))


clusters(kume1, kume2)
# Out:
# {'qcut', 'lambda', 'miuul', 'function'}

# %% [markdown]
# # CASE STUDY-2:  LIST COMPREHENSION

# %% [markdown]
# ## GÖREV-1:
# ## List Comprehension yapısı kullanarak car_crashes verisindeki numerik değişkenlerin isimlerini büyük harfe çeviriniz ve başına NUM ekleyiniz. (Numerik olmayan değişkenlerin de isimleri büyümeli, tek bir List Comprehension yapısı kullanılmalı.)
#
# ###### Beklenen Çıktı:
# ###### ['NUM_TOTAL',
# ######  'NUM_SPEEDING',
# ######  'NUM_ALCOHOL',
# ######  'NUM_NOT_DISTRACTED',
# ######  'NUM_NO_PREVIOUS',
# ######  'NUM_INS_PREMIUM',
# ######  'NUM_INS_LOSSES',
# ######  'ABBREV']

# %%
import seaborn as sns
df = sns.load_dataset("car_crashes")
df.columns
# Out:
# Index(['total', 'speeding', 'alcohol', 'not_distracted', 'no_previous',
#        'ins_premium', 'ins_losses', 'abbrev'],
#       dtype='object')

# %%
num_cols = ["NUM_" + col.upper() if df[col].dtype != 'O' else col.upper() for col in df.columns]
num_cols
# Out:
# ['NUM_TOTAL',
#  'NUM_SPEEDING',
#  'NUM_ALCOHOL',
#  'NUM_NOT_DISTRACTED',
#  'NUM_NO_PREVIOUS',
#  'NUM_INS_PREMIUM',
#  'NUM_INS_LOSSES',
#  'ABBREV']

# %% [markdown]
# ## GÖREV-2:
# ## List Comprehension yapısı kullanarak car_crashes verisinde isminde "no" barındırmayan değişkenlerin isimlerinin sonuna "FLAG" yazınız. (Tüm değişkenlerin isimleri büyük harf olmalı, tek bir List Comprehension kullanılmalı.)
#
# ###### Beklenen Çıktı:
# ###### ['TOTAL_FLAG',
# ######  'SPEEDING_FLAG',
# ######  'ALCOHOL_FLAG',
# ######  'NOT_DISTRACTED',
# ######  'NO_PREVIOUS',
# ######  'INS_PREMIUM_FLAG',
# ######  'INS_LOSSES_FLAG',
# ######  'ABBREV_FLAG']

# %%
df = sns.load_dataset("car_crashes")

flag_cols = [col.upper() + "_FLAG" if "no" not in col else col.upper() for col in df.columns]
flag_cols
# Out:
# ['TOTAL_FLAG',
#  'SPEEDING_FLAG',
#  'ALCOHOL_FLAG',
#  'NOT_DISTRACTED',
#  'NO_PREVIOUS',
#  'INS_PREMIUM_FLAG',
#  'INS_LOSSES_FLAG',
#  'ABBREV_FLAG']

# %% [markdown]
# ## GÖREV-3:
# ## List Comprehension yapısı kullanarak aşağıda verilen değişken isimlerinden FARKLI olan değişkenlerin isimlerini seçiniz ve yeni bir dataframe oluşturunuz.
#
# #### og_list = ["abbrev", "no_previous"]

# %%
og_list = ["abbrev", "no_previous"]


new_cols = [col for col in df.columns if col not in og_list]            # Out[94]: ['total', 'speeding', 'alcohol', 'not_distracted', 'ins_premium', 'ins_losses']

new_df = df[new_cols]
new_df.head()
# Out:
#    total  speeding  alcohol  not_distracted  ins_premium  ins_losses
# 0   18.8     7.332    5.640          18.048       784.55      145.08
# 1   18.1     7.421    4.525          16.290      1053.48      133.93
# 2   18.6     6.510    5.208          15.624       899.47      110.35
# 3   22.4     4.032    5.824          21.056       827.34      142.39
# 4   12.0     4.200    3.360          10.920       878.41      165.63
